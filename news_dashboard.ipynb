# %% [markdown]
# ## News dashboard (latest headlines + measured impact)
#
# This notebook reads outputs created by `python3 run_daily.py`:
# - `logs/latest_news.json`
# - `logs/news_impact.csv`
#
# If you haven't run the daily pipeline yet, run:
#
# ```bash
# python3 run_daily.py
# ```

# %%
from pathlib import Path

import pandas as pd

from pipeline.news import load_latest_news_dataframe

logs_dir = Path("logs")
df = load_latest_news_dataframe(logs_dir)

# Pick a compact set of columns to view
cols = [
    c
    for c in [
        "symbol",
        "published_at_utc",
        "sentiment",
        "title",
        "ret_1d",
        "ret_3d",
        "ret_5d",
        "mkt_adj_ret_1d",
        "mkt_adj_ret_3d",
        "mkt_adj_ret_5d",
        "link",
    ]
    if c in df.columns
]

pd.set_option("display.max_colwidth", 120)
df.loc[:, cols].head(30) if not df.empty else df
# Out:
#    symbol published_at_utc  sentiment title ret_1d ret_3d ret_5d  \
# 0    AAPL              NaT       0.25  None    NaN    NaN    NaN
# 1    AAPL              NaT      -0.25  None    NaN    NaN    NaN
# 2    AAPL              NaT       0.00  None    NaN    NaN    NaN
# 3    AAPL              NaT       0.25  None    NaN    NaN    NaN
# 4    AAPL              NaT       0.00  None    NaN    NaN    NaN
# 5    AAPL              NaT       0.00  None    NaN    NaN    NaN
# 6    AAPL              NaT       0.00  None    NaN    NaN    NaN
# 7    AAPL              NaT       0.00  None    NaN    NaN    NaN
# 8    MSFT              NaT       0.00  None    NaN    NaN    NaN
# 9    MSFT              NaT       0.00  None    NaN    NaN    NaN
# 10   MSFT              NaT       0.00  None    NaN    NaN    NaN
# 11   MSFT              NaT       0.00  None    NaN    NaN    NaN
# 12   MSFT              NaT       0.25  None    NaN    NaN    NaN
# ...
